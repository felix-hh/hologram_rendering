# %%
import numpy as np
import matplotlib.pyplot as plt

from lightfield_utils import load_lightfield, get_average_lightfield
from pathlib import Path

# %load_ext autoreload
# %autoreload 2

# %%
lightfield = load_lightfield("rendered_views_2021_4_29_48x192x572x440.npy")
# Out:
# Loaded lightfield with dtype: float32 and shape: (48, 192, 440, 572, 3)

# %%
average_lf = get_average_lightfield(lightfield)

# %%
plt.figure(figsize= (10,10))
plt.imshow(average_lf)

# %%
def display_average_lightfield(path):
    lf = load_lightfield(path)
    average_lf = get_average_lightfield(lf)
    plt.figure(figsize= (10,10))
    plt.imshow(average_lf)

# %%
display_average_lightfield("original_lightfield.npy")

# %%
import pickle 

with open ("2021_04_15_Benton_raw_lightfield.npy", "rb") as input_file:
    lightfield2 = pickle.load(input_file)

for i in tqdm.tqdm(range(10)):
    average_lf = get_average_lightfield(lightfield2)
    
plt.figure(figsize= (10,10))
plt.imshow(average_lf)
